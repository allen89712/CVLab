# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
##資料處理

#將 mnist 資料集載入
(train_images, _), (test_images, _) = tf.keras.datasets.mnist.load_data()

#轉換資料成四維tensor可處理的型態
train_images = train_images.reshape(train_images.shape[0], 28, 28, 1).astype('float32')
test_images  = test_images.reshape(test_images.shape[0], 28, 28, 1).astype('float32')

# 資料正規化
train_images /= 255
test_images  /= 255

# 使資料容易訓練
train_images[train_images >= 0.5] = 1
train_images[train_images < 0.5]  = 0
test_images[test_images >= 0.5]   = 1
test_images[test_images < 0.5]    = 0
print("train shape:",train_images.shape)
print("test shape", test_images.shape)
# Out:
# train shape: (60000, 28, 28, 1)
# test shape (10000, 28, 28, 1)

# %%
##視覺化測試資料集
plt.figure(figsize = (8,8))
for i in range(25):

    plt.subplot(5,5,i+1)
    plt.imshow(train_images[i], cmap = plt.cm.binary )
    plt.xticks([])
    plt.yticks([])

plt.show()

# %%
factor = 0.17
#在影像上添加高斯雜訊
train_noisy_images = train_images + factor * np.random.normal(loc = 0.0,scale = 1.0,size = train_images.shape)
test_noisy_images = test_images + factor * np.random.normal(loc = 0.0,scale = 1.0,size = test_images.shape)

#使用numpy下的clip函示將像素值控制在0到1之間
train_noisy_images = np.clip(train_noisy_images,0,1)
test_noisy_images = np.clip(test_noisy_images,0,1)
#轉換資料成四維tensor可處理的型態
x_train_noise = train_noisy_images.reshape(60000,28,28,1)
x_test_noise  = test_noisy_images.reshape(10000,28,28,1)

# %%
plt.figure(figsize = (8,8))

for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(x_train_noise[i].reshape(1,28,28)[0], cmap = plt.cm.binary )
    plt.xticks([])
    plt.yticks([])

plt.show()

# %%
##Convolution autoEncoder實作

#建立input layer
input_img = tf.keras.layers.Input(shape = (28, 28, 1))

#Encoder部分第一行使用16個3*3的kernal激活函數ReLU, padding方式為same使其與輸入圖片維持一樣大小
encoder = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)

#Encoder第二行做maxpooling使用2*2的kernal, padding方式也為same使其大小為輸入圖片之一半
encoder = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(encoder)

#重複上述兩行
encoder = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoder)
encoder = tf.keras.layers.MaxPooling2D((2, 2), padding='same', name="latent_space")(encoder)
#latent_space為第二次maxpooling後的convolution layer命名通常這個位子被稱為"潛在空間"即Encoder的輸出特徵圖

#Decoder部分第一行使用上採樣UpSampling2D將特徵圖的尺寸擴大一倍進行重建
decoder = tf.keras.layers.UpSampling2D((2, 2))(encoder)

#第二行使用16個3*3的kernal激活函數ReLU, padding方式為same使其與輸入圖片維持一樣大小
decoder = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(decoder)
decoder = tf.keras.layers.UpSampling2D((2, 2))(decoder)

#最後的convolution layer使用1個3*3的kernal激活函數使用sigmoid以確保輸出的像素值為0-1之間, 符合灰階影像
decoder = tf.keras.layers.Conv2D(1, (3, 3), activation = "sigmoid", padding = "same")(decoder)

#建立model組合輸入層跟Decoder部分命名為convolution_AE
conv_autoencoder = tf.keras.models.Model(input_img, decoder, name="convolution_AE")

#編譯模型，指定優化器為 Adam，損失函數為binary_crossentropy
conv_autoencoder.compile(optimizer='Adam', loss='binary_crossentropy', metrics=["accuracy"])

#顯示模型摘要，包括各層的名稱、輸出形狀和參數數量
conv_autoencoder.summary()

#進行模型的訓練 使用 x_train_noise 作為輸入，train_images 作為目標，進行 50 個訓練迭代，每批次大小為 256
#同時，在訓練期間，使用 x_test_noise 和 test_images 進行驗證, 訓練過程的進度和結果將以詳細的日誌verbose = 2顯示
conv_autoencoder.fit(x_train_noise, train_images, epochs=100, batch_size=128, shuffle=True,
                     validation_data=(x_test_noise, test_images), verbose = 2)
# Out:
# Model: "convolution_AE"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 16)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 8)         1160
# _________________________________________________________________
# latent_space (MaxPooling2D)  (None, 7, 7, 8)           0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 14, 14, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 16)        1168
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 1)         145
# =================================================================
# Total params: 2,633
# Trainable params: 2,633
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 469/469 - 6s - loss: 0.1573 - accuracy: 0.9398 - val_loss: 0.0631 - val_accuracy: 0.9753
# Epoch 2/100
# 469/469 - 2s - loss: 0.0549 - accuracy: 0.9783 - val_loss: 0.0479 - val_accuracy: 0.9813
# Epoch 3/100
# 469/469 - 2s - loss: 0.0458 - accuracy: 0.9819 - val_loss: 0.0424 - val_accuracy: 0.9833
# Epoch 4/100
# 469/469 - 2s - loss: 0.0417 - accuracy: 0.9836 - val_loss: 0.0395 - val_accuracy: 0.9844
# Epoch 5/100
# 469/469 - 2s - loss: 0.0392 - accuracy: 0.9846 - val_loss: 0.0375 - val_accuracy: 0.9854
# Epoch 6/100
# 469/469 - 2s - loss: 0.0374 - accuracy: 0.9853 - val_loss: 0.0360 - val_accuracy: 0.9860
# Epoch 7/100
# 469/469 - 2s - loss: 0.0360 - accuracy: 0.9859 - val_loss: 0.0348 - val_accuracy: 0.9862
# Epoch 8/100
# 469/469 - 2s - loss: 0.0348 - accuracy: 0.9864 - val_loss: 0.0338 - val_accuracy: 0.9867
# Epoch 9/100
# 469/469 - 2s - loss: 0.0338 - accuracy: 0.9868 - val_loss: 0.0329 - val_accuracy: 0.9871
# Epoch 10/100
# 469/469 - 2s - loss: 0.0330 - accuracy: 0.9871 - val_loss: 0.0320 - val_accuracy: 0.9876
# Epoch 11/100
# 469/469 - 2s - loss: 0.0322 - accuracy: 0.9874 - val_loss: 0.0316 - val_accuracy: 0.9878
# Epoch 12/100
# 469/469 - 2s - loss: 0.0316 - accuracy: 0.9877 - val_loss: 0.0307 - val_accuracy: 0.9881
# Epoch 13/100
# 469/469 - 2s - loss: 0.0309 - accuracy: 0.9880 - val_loss: 0.0301 - val_accuracy: 0.9884
# Epoch 14/100
# 469/469 - 2s - loss: 0.0304 - accuracy: 0.9882 - val_loss: 0.0296 - val_accuracy: 0.9885
# Epoch 15/100
# 469/469 - 2s - loss: 0.0299 - accuracy: 0.9884 - val_loss: 0.0292 - val_accuracy: 0.9888
# Epoch 16/100
# 469/469 - 2s - loss: 0.0295 - accuracy: 0.9886 - val_loss: 0.0288 - val_accuracy: 0.9888
# Epoch 17/100
# 469/469 - 2s - loss: 0.0291 - accuracy: 0.9887 - val_loss: 0.0284 - val_accuracy: 0.9891
# Epoch 18/100
# 469/469 - 2s - loss: 0.0287 - accuracy: 0.9889 - val_loss: 0.0280 - val_accuracy: 0.9891
# Epoch 19/100
# 469/469 - 2s - loss: 0.0284 - accuracy: 0.9890 - val_loss: 0.0277 - val_accuracy: 0.9893
# Epoch 20/100
# 469/469 - 2s - loss: 0.0280 - accuracy: 0.9892 - val_loss: 0.0273 - val_accuracy: 0.9895
# Epoch 21/100
# 469/469 - 2s - loss: 0.0277 - accuracy: 0.9893 - val_loss: 0.0270 - val_accuracy: 0.9896
# Epoch 22/100
# 469/469 - 2s - loss: 0.0275 - accuracy: 0.9894 - val_loss: 0.0268 - val_accuracy: 0.9897
# Epoch 23/100
# 469/469 - 2s - loss: 0.0272 - accuracy: 0.9895 - val_loss: 0.0265 - val_accuracy: 0.9897
# Epoch 24/100
# 469/469 - 2s - loss: 0.0270 - accuracy: 0.9896 - val_loss: 0.0264 - val_accuracy: 0.9899
# Epoch 25/100
# 469/469 - 2s - loss: 0.0268 - accuracy: 0.9897 - val_loss: 0.0261 - val_accuracy: 0.9900
# Epoch 26/100
# 469/469 - 2s - loss: 0.0266 - accuracy: 0.9898 - val_loss: 0.0259 - val_accuracy: 0.9900
# Epoch 27/100
# 469/469 - 2s - loss: 0.0264 - accuracy: 0.9898 - val_loss: 0.0257 - val_accuracy: 0.9901
# Epoch 28/100
# 469/469 - 2s - loss: 0.0262 - accuracy: 0.9899 - val_loss: 0.0257 - val_accuracy: 0.9901
# Epoch 29/100
# 469/469 - 2s - loss: 0.0260 - accuracy: 0.9900 - val_loss: 0.0253 - val_accuracy: 0.9903
# Epoch 30/100
# 469/469 - 2s - loss: 0.0257 - accuracy: 0.9901 - val_loss: 0.0251 - val_accuracy: 0.9903
# Epoch 31/100
# 469/469 - 2s - loss: 0.0256 - accuracy: 0.9902 - val_loss: 0.0249 - val_accuracy: 0.9905
# Epoch 32/100
# 469/469 - 2s - loss: 0.0254 - accuracy: 0.9902 - val_loss: 0.0247 - val_accuracy: 0.9906
# Epoch 33/100
# 469/469 - 2s - loss: 0.0252 - accuracy: 0.9903 - val_loss: 0.0246 - val_accuracy: 0.9906
# Epoch 34/100
# 469/469 - 2s - loss: 0.0251 - accuracy: 0.9904 - val_loss: 0.0244 - val_accuracy: 0.9907
# Epoch 35/100
# 469/469 - 2s - loss: 0.0250 - accuracy: 0.9904 - val_loss: 0.0245 - val_accuracy: 0.9906
# Epoch 36/100
# 469/469 - 2s - loss: 0.0249 - accuracy: 0.9905 - val_loss: 0.0243 - val_accuracy: 0.9907
# Epoch 37/100
# 469/469 - 2s - loss: 0.0248 - accuracy: 0.9905 - val_loss: 0.0241 - val_accuracy: 0.9908
# Epoch 38/100
# 469/469 - 2s - loss: 0.0247 - accuracy: 0.9906 - val_loss: 0.0243 - val_accuracy: 0.9908
# Epoch 39/100
# 469/469 - 2s - loss: 0.0246 - accuracy: 0.9906 - val_loss: 0.0239 - val_accuracy: 0.9909
# Epoch 40/100
# 469/469 - 2s - loss: 0.0246 - accuracy: 0.9906 - val_loss: 0.0240 - val_accuracy: 0.9909
# Epoch 41/100
# 469/469 - 2s - loss: 0.0244 - accuracy: 0.9907 - val_loss: 0.0239 - val_accuracy: 0.9910
# Epoch 42/100
# 469/469 - 2s - loss: 0.0244 - accuracy: 0.9907 - val_loss: 0.0237 - val_accuracy: 0.9910
# Epoch 43/100
# 469/469 - 2s - loss: 0.0243 - accuracy: 0.9907 - val_loss: 0.0237 - val_accuracy: 0.9909
# Epoch 44/100
# 469/469 - 2s - loss: 0.0242 - accuracy: 0.9908 - val_loss: 0.0237 - val_accuracy: 0.9910
# Epoch 45/100
# 469/469 - 2s - loss: 0.0242 - accuracy: 0.9908 - val_loss: 0.0236 - val_accuracy: 0.9911
# Epoch 46/100
# 469/469 - 2s - loss: 0.0241 - accuracy: 0.9908 - val_loss: 0.0235 - val_accuracy: 0.9911
# Epoch 47/100
# 469/469 - 2s - loss: 0.0240 - accuracy: 0.9909 - val_loss: 0.0240 - val_accuracy: 0.9910
# Epoch 48/100
# 469/469 - 2s - loss: 0.0240 - accuracy: 0.9909 - val_loss: 0.0233 - val_accuracy: 0.9912
# Epoch 49/100
# 469/469 - 2s - loss: 0.0239 - accuracy: 0.9909 - val_loss: 0.0233 - val_accuracy: 0.9912
# Epoch 50/100
# 469/469 - 2s - loss: 0.0238 - accuracy: 0.9909 - val_loss: 0.0233 - val_accuracy: 0.9912
# Epoch 51/100
# 469/469 - 2s - loss: 0.0238 - accuracy: 0.9910 - val_loss: 0.0232 - val_accuracy: 0.9912
# Epoch 52/100
# 469/469 - 2s - loss: 0.0237 - accuracy: 0.9910 - val_loss: 0.0232 - val_accuracy: 0.9912
# Epoch 53/100
# 469/469 - 2s - loss: 0.0237 - accuracy: 0.9910 - val_loss: 0.0233 - val_accuracy: 0.9911
# Epoch 54/100
# 469/469 - 2s - loss: 0.0236 - accuracy: 0.9910 - val_loss: 0.0230 - val_accuracy: 0.9913
# Epoch 55/100
# 469/469 - 2s - loss: 0.0235 - accuracy: 0.9911 - val_loss: 0.0231 - val_accuracy: 0.9912
# Epoch 56/100
# 469/469 - 2s - loss: 0.0235 - accuracy: 0.9911 - val_loss: 0.0229 - val_accuracy: 0.9914
# Epoch 57/100
# 469/469 - 2s - loss: 0.0234 - accuracy: 0.9911 - val_loss: 0.0228 - val_accuracy: 0.9914
# Epoch 58/100
# 469/469 - 2s - loss: 0.0233 - accuracy: 0.9911 - val_loss: 0.0230 - val_accuracy: 0.9913
# Epoch 59/100
# 469/469 - 2s - loss: 0.0232 - accuracy: 0.9912 - val_loss: 0.0227 - val_accuracy: 0.9914
# Epoch 60/100
# 469/469 - 2s - loss: 0.0232 - accuracy: 0.9912 - val_loss: 0.0227 - val_accuracy: 0.9914
# Epoch 61/100
# 469/469 - 2s - loss: 0.0231 - accuracy: 0.9912 - val_loss: 0.0227 - val_accuracy: 0.9914
# Epoch 62/100
# 469/469 - 2s - loss: 0.0230 - accuracy: 0.9912 - val_loss: 0.0232 - val_accuracy: 0.9913
# Epoch 63/100
# 469/469 - 2s - loss: 0.0230 - accuracy: 0.9913 - val_loss: 0.0226 - val_accuracy: 0.9914
# Epoch 64/100
# 469/469 - 2s - loss: 0.0229 - accuracy: 0.9913 - val_loss: 0.0224 - val_accuracy: 0.9916
# Epoch 65/100
# 469/469 - 2s - loss: 0.0229 - accuracy: 0.9913 - val_loss: 0.0223 - val_accuracy: 0.9915
# Epoch 66/100
# 469/469 - 2s - loss: 0.0228 - accuracy: 0.9913 - val_loss: 0.0223 - val_accuracy: 0.9916
# Epoch 67/100
# 469/469 - 2s - loss: 0.0228 - accuracy: 0.9914 - val_loss: 0.0224 - val_accuracy: 0.9915
# Epoch 68/100
# 469/469 - 2s - loss: 0.0227 - accuracy: 0.9914 - val_loss: 0.0222 - val_accuracy: 0.9916
# Epoch 69/100
# 469/469 - 2s - loss: 0.0227 - accuracy: 0.9914 - val_loss: 0.0221 - val_accuracy: 0.9916
# Epoch 70/100
# 469/469 - 2s - loss: 0.0226 - accuracy: 0.9914 - val_loss: 0.0221 - val_accuracy: 0.9917
# Epoch 71/100
# 469/469 - 2s - loss: 0.0226 - accuracy: 0.9914 - val_loss: 0.0220 - val_accuracy: 0.9916
# Epoch 72/100
# 469/469 - 2s - loss: 0.0225 - accuracy: 0.9915 - val_loss: 0.0223 - val_accuracy: 0.9916
# Epoch 73/100
# 469/469 - 2s - loss: 0.0225 - accuracy: 0.9915 - val_loss: 0.0221 - val_accuracy: 0.9916
# Epoch 74/100
# 469/469 - 2s - loss: 0.0224 - accuracy: 0.9915 - val_loss: 0.0219 - val_accuracy: 0.9918
# Epoch 75/100
# 469/469 - 2s - loss: 0.0224 - accuracy: 0.9915 - val_loss: 0.0219 - val_accuracy: 0.9917
# Epoch 76/100
# 469/469 - 2s - loss: 0.0224 - accuracy: 0.9915 - val_loss: 0.0218 - val_accuracy: 0.9918
# Epoch 77/100
# 469/469 - 2s - loss: 0.0224 - accuracy: 0.9915 - val_loss: 0.0218 - val_accuracy: 0.9918
# Epoch 78/100
# 469/469 - 2s - loss: 0.0223 - accuracy: 0.9915 - val_loss: 0.0219 - val_accuracy: 0.9917
# Epoch 79/100
# 469/469 - 2s - loss: 0.0223 - accuracy: 0.9916 - val_loss: 0.0220 - val_accuracy: 0.9916
# Epoch 80/100
# 469/469 - 2s - loss: 0.0223 - accuracy: 0.9916 - val_loss: 0.0217 - val_accuracy: 0.9918
# Epoch 81/100
# 469/469 - 2s - loss: 0.0222 - accuracy: 0.9916 - val_loss: 0.0216 - val_accuracy: 0.9918
# Epoch 82/100
# 469/469 - 2s - loss: 0.0222 - accuracy: 0.9916 - val_loss: 0.0216 - val_accuracy: 0.9919
# Epoch 83/100
# 469/469 - 2s - loss: 0.0221 - accuracy: 0.9916 - val_loss: 0.0216 - val_accuracy: 0.9919
# Epoch 84/100
# 469/469 - 2s - loss: 0.0221 - accuracy: 0.9916 - val_loss: 0.0216 - val_accuracy: 0.9919
# Epoch 85/100
# 469/469 - 2s - loss: 0.0221 - accuracy: 0.9916 - val_loss: 0.0216 - val_accuracy: 0.9919
# Epoch 86/100
# 469/469 - 2s - loss: 0.0220 - accuracy: 0.9917 - val_loss: 0.0215 - val_accuracy: 0.9919
# Epoch 87/100
# 469/469 - 2s - loss: 0.0220 - accuracy: 0.9917 - val_loss: 0.0221 - val_accuracy: 0.9916
# Epoch 88/100
# 469/469 - 2s - loss: 0.0220 - accuracy: 0.9917 - val_loss: 0.0215 - val_accuracy: 0.9919
# Epoch 89/100
# 469/469 - 2s - loss: 0.0219 - accuracy: 0.9917 - val_loss: 0.0218 - val_accuracy: 0.9917
# Epoch 90/100
# 469/469 - 2s - loss: 0.0219 - accuracy: 0.9917 - val_loss: 0.0214 - val_accuracy: 0.9920
# Epoch 91/100
# 469/469 - 2s - loss: 0.0219 - accuracy: 0.9917 - val_loss: 0.0215 - val_accuracy: 0.9919
# Epoch 92/100
# 469/469 - 2s - loss: 0.0219 - accuracy: 0.9917 - val_loss: 0.0213 - val_accuracy: 0.9920
# Epoch 93/100
# 469/469 - 2s - loss: 0.0218 - accuracy: 0.9917 - val_loss: 0.0217 - val_accuracy: 0.9919
# Epoch 94/100
# 469/469 - 2s - loss: 0.0218 - accuracy: 0.9918 - val_loss: 0.0214 - val_accuracy: 0.9920
# Epoch 95/100
# 469/469 - 2s - loss: 0.0218 - accuracy: 0.9918 - val_loss: 0.0212 - val_accuracy: 0.9920
# Epoch 96/100
# 469/469 - 2s - loss: 0.0218 - accuracy: 0.9918 - val_loss: 0.0212 - val_accuracy: 0.9920
# Epoch 97/100
# 469/469 - 2s - loss: 0.0217 - accuracy: 0.9918 - val_loss: 0.0213 - val_accuracy: 0.9920
# Epoch 98/100
# 469/469 - 2s - loss: 0.0217 - accuracy: 0.9918 - val_loss: 0.0211 - val_accuracy: 0.9920
# Epoch 99/100
# 469/469 - 2s - loss: 0.0216 - accuracy: 0.9918 - val_loss: 0.0212 - val_accuracy: 0.9920
# Epoch 100/100
# 469/469 - 2s - loss: 0.0216 - accuracy: 0.9918 - val_loss: 0.0211 - val_accuracy: 0.9920

# %%
##結果顯示
#將測試資料放入模型去除雜訊
decoded_imgs = conv_autoencoder.predict(x_test_noise)

n = 10
plt.figure(figsize=(20,4))
for i in range(10):

    #建立子圖ax表示共3行n列, i+1=1~10確保從第一列開始顯示
    ax = plt.subplot(3, n, i + 1)

    #顯示原始圖片
    plt.imshow(test_images[i].reshape(28, 28))
    #轉為灰階圖
    plt.gray()
    #隱藏座標軸
    plt.xticks([])
    plt.yticks([])

    #建立子圖ax表示共3行n列, i+n+1=11~20確保從第二列開始顯示
    ax = plt.subplot(3, n, i + n + 1)
    #顯示加入雜訊後之圖片
    plt.imshow(x_test_noise[i].reshape(28, 28))
    plt.gray()
    plt.xticks([])
    plt.yticks([])

    #建立子圖ax表示共3行n列, i+n+n+1=21~30確保從第三列開始顯示
    ax = plt.subplot(3, n, i + n + n + 1)
    #顯示經過AutoEncoder的結果
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    plt.xticks([])
    plt.yticks([])
plt.show()

# %% [markdown]
# # 新增區段
